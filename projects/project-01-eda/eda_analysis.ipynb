# %%
from datetime import datetime; print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib  # Add this line

print("✅ Environment setup successful!")
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
# Out:
# Run: 2026-02-23 16:24:12
# ✅ Environment setup successful!
# pandas: 3.0.0
# numpy: 2.4.2
# matplotlib: 3.10.8
# seaborn: 0.13.2

# %%
from datetime import datetime; print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Load the Titanic dataset
df = pd.read_csv('../../datasets/titanic.csv')

# Display first few rows
print(f"Dataset shape: {df.shape[0]} rows, {df.shape[1]} columns")
print("\nFirst x rows:")
df.head(25)
# Out:
# Run: 2026-02-23 16:24:12
# Dataset shape: 891 rows, 12 columns
#
# First x rows:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
#                                                        Name     Sex   Age  \
# 0                                   Braund, Mr. Owen Harris    male  22.0
# 1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0
# 2                                    Heikkinen, Miss. Laina  female  26.0
# 3              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                  Allen, Mr. William Henry    male  35.0
# 5                                          Moran, Mr. James    male   NaN
# 6                                   McCarthy, Mr. Timothy J    male  54.0
# 7                            Palsson, Master. Gosta Leonard    male   2.0
# 8         Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                       Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                          Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                                 Bonnell, Miss. Elizabeth  female  58.0
# 12                           Saundercock, Mr. William Henry    male  20.0
# 13                              Andersson, Mr. Anders Johan    male  39.0
# 14                     Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15                         Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                                     Rice, Master. Eugene    male   2.0
# 17                             Williams, Mr. Charles Eugene    male   NaN
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)  female  31.0
# 19                                  Masselmani, Mrs. Fatima  female   NaN
# 20                                     Fynney, Mr. Joseph J    male  35.0
# 21                                    Beesley, Mr. Lawrence    male  34.0
# 22                              McGowan, Miss. Anna "Annie"  female  15.0
# 23                             Sloper, Mr. William Thompson    male  28.0
# 24                            Palsson, Miss. Torborg Danira  female   8.0
#
#     SibSp  Parch            Ticket     Fare Cabin Embarked
# 0       1      0         A/5 21171   7.2500   NaN        S
# 1       1      0          PC 17599  71.2833   C85        C
# 2       0      0  STON/O2. 3101282   7.9250   NaN        S
# 3       1      0            113803  53.1000  C123        S
# 4       0      0            373450   8.0500   NaN        S
# 5       0      0            330877   8.4583   NaN        Q
# 6       0      0             17463  51.8625   E46        S
# 7       3      1            349909  21.0750   NaN        S
# 8       0      2            347742  11.1333   NaN        S
# 9       1      0            237736  30.0708   NaN        C
# 10      1      1           PP 9549  16.7000    G6        S
# 11      0      0            113783  26.5500  C103        S
# 12      0      0         A/5. 2151   8.0500   NaN        S
# 13      1      5            347082  31.2750   NaN        S
# 14      0      0            350406   7.8542   NaN        S
# 15      0      0            248706  16.0000   NaN        S
# 16      4      1            382652  29.1250   NaN        Q
# 17      0      0            244373  13.0000   NaN        S
# 18      1      0            345763  18.0000   NaN        S
# 19      0      0              2649   7.2250   NaN        C
# 20      0      0            239865  26.0000   NaN        S
# 21      0      0            248698  13.0000   D56        S
# 22      0      0            330923   8.0292   NaN        Q
# 23      0      0            113788  35.5000    A6        S
# 24      3      1            349909  21.0750   NaN        S

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
print(df.info())  # Data types and missing values
# Out:
# Run: 2026-02-23 16:24:12
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# None

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
print(df.describe().round(2))
# Out:
# Run: 2026-02-23 16:24:12
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")

# Calculate then print specific age statistics
mean_age = df['Age'].mean()
print(f"Mean age: {mean_age:.2f}")

median_age = df['Age'].median()
print(f"Median age: {median_age:.2f}")

print(f"Mode Age:   {df['Age'].mode()[0]:.2f}")

std_age = df['Age'].std()
print(f"Std Age: {std_age:.2f}")
# Out:
# Run: 2026-02-23 16:24:12
# Mean age: 29.70
# Median age: 28.00
# Mode Age:   24.00
# Std Age: 14.53

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")

# Calculate then print specific fare statistics
mean_fare = df['Fare'].mean()
print(f"Mean Fare: {mean_fare:.2f}")

median_fare = df['Fare'].median()
print(f"Median Fare: {median_fare:.2f}")

print(f"Mode Fare:   {df['Fare'].mode()[0]:.2f}")

std_fare = df['Fare'].std()
print(f"Std Fare: {std_fare:.2f}")

fare_skew = df['Fare'].skew()
print (f"Skew Fare:= {fare_skew:.2f}")

print("\nFare by PClass\n-------------------")
df.groupby('Pclass')['Fare'].agg(['count', 'mean', 'median', 'std', 'min', 'max'])
# Out:
# Run: 2026-02-23 16:24:12
# Mean Fare: 32.20
# Median Fare: 14.45
# Mode Fare:   8.05
# Std Fare: 49.69
# Skew Fare:= 4.79
#
# Fare by PClass
# -------------------
#         count       mean   median        std  min       max
# Pclass
# 1         216  84.154687  60.2875  78.380373  0.0  512.3292
# 2         184  20.662183  14.2500  13.417399  0.0   73.5000
# 3         491  13.675550   8.0500  11.778142  0.0   69.5500

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Deciles from 0 to 100% (including min and max)
print(df['Age'].quantile([i/10 for i in range(11)]))
# This gives: 0.0, 0.1, 0.2, 0.3, ... 0.9, 1.0
# Out:
# Run: 2026-02-23 16:24:12
# 0.0     0.42
# 0.1    14.00
# 0.2    19.00
# 0.3    22.00
# 0.4    25.00
# 0.5    28.00
# 0.6    31.80
# 0.7    36.00
# 0.8    41.00
# 0.9    50.00
# 1.0    80.00
# Name: Age, dtype: float64

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Percentiles
print(df['Age'].quantile([0.25, 0.5, 0.75, 0.95, 0.99]))
# Out:
# Run: 2026-02-23 16:24:12
# 0.25    20.125
# 0.50    28.000
# 0.75    38.000
# 0.95    56.000
# 0.99    65.870
# Name: Age, dtype: float64

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Survival rate
survival_rate = df['Survived'].mean()
print(f"Overall survival rate: {survival_rate:.2%}")
# Out:
# Run: 2026-02-23 16:24:12
# Overall survival rate: 38.38%

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Group statistics

print("\nSurvival Rate by Sex\n-------------------")
print(df.groupby('Sex')['Survived'].mean())
print("\nSurvival Rate by Pclass\n-------------------")
print(df.groupby('Pclass')['Survived'].mean())
#print(df.groupby('Fare')['Survived'].mean())
# Out:
# Run: 2026-02-23 16:24:12
#
# Survival Rate by Sex
# -------------------
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
#
# Survival Rate by Pclass
# -------------------
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
std_age = df['Age'].std()
var_age = df['Age'].var()

print (f"std_age: {std_age:.2f}")  # standard deviation
print(f"variance_age: {var_age:.2f}")   # variance (std squared)
# Out:
# Run: 2026-02-23 16:24:12
# std_age: 14.53
# variance_age: 211.02

# %%
from datetime import datetime; print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Visualizations
plt.figure(figsize=(10, 6))
plt.hist(df['Age'].dropna(), bins=30, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Passenger Ages')
plt.show()
# Out:
# Run: 2026-02-23 16:24:12

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Visualizations
plt.figure(figsize=(10, 6))
plt.hist(df['Fare'].dropna(), bins=50, edgecolor='black')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Passenger Fares')
plt.show()
# Out:
# Run: 2026-02-23 16:24:13

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")

age_skew = df['Age'].skew()
print (f"age_skew = {age_skew:.2f}")
# Out:
# Run: 2026-02-23 16:24:13
# age_skew = 0.39

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
print(f"Mean:   {df['Age'].mean():.2f}")
print(f"Median: {df['Age'].median():.2f}")
print(f"Mode:   {df['Age'].mode()[0]:.2f}")
print(f"Std:    {df['Age'].std():.2f}")
# Out:
# Run: 2026-02-23 16:24:13
# Mean:   29.70
# Median: 28.00
# Mode:   24.00
# Std:    14.53

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")} \n-------------------------")
df['Sex'].value_counts()
# Out:
# Run: 2026-02-23 16:24:13
# -------------------------
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
# Percentages
passenger_sex = df['Sex'].value_counts(normalize=True)
display(passenger_sex)

survival_by_sex = df.groupby('Sex')['Survived'].mean()
print ("\nSurvival by Sex\n-------------------")
display(survival_by_sex)

survival_stats_by_sex = df.groupby('Sex')['Survived'].agg(['count', 'sum', 'mean'])
print ("\nSurvival Stats by Sex\n-------------------")
display(survival_stats_by_sex)

survival_stats_by_pclass = df.groupby('Pclass')['Survived'].agg(['count', 'sum', 'mean'])
print ("\nSurvival Stats by Pclass\n-------------------")
display(survival_stats_by_pclass)

survival_stats = df.groupby(['Pclass', 'Sex'])['Survived'].agg(['count', 'sum', 'mean'])
print("\nSurvival Stats by Pclass and Sex\n-------------------")
display(survival_stats)
# Out:
# Run: 2026-02-23 16:26:05
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64
# Survival by Sex
# -------------------
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
# Survival Stats by Sex
# -------------------
#         count  sum      mean
# Sex
# female    314  233  0.742038
# male      577  109  0.188908
# Survival Stats by Pclass
# -------------------
#         count  sum      mean
# Pclass
# 1         216  136  0.629630
# 2         184   87  0.472826
# 3         491  119  0.242363
# Survival Stats by Pclass and Sex
# -------------------
#                count  sum      mean
# Pclass Sex
# 1      female     94   91  0.968085
#        male      122   45  0.368852
# 2      female     76   70  0.921053
#        male      108   17  0.157407
# 3      female    144   72  0.500000
#        male      347   47  0.135447

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")
df.groupby('Pclass')['Fare'].agg(['count', 'mean', 'median', 'std', 'min', 'max'])
# Out:
# Run: 2026-02-23 16:24:13
#         count       mean   median        std  min       max
# Pclass
# 1         216  84.154687  60.2875  78.380373  0.0  512.3292
# 2         184  20.662183  14.2500  13.417399  0.0   73.5000
# 3         491  13.675550   8.0500  11.778142  0.0   69.5500

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}")

# Dataset Profile — row counts, field population, and value ranges

total_rows = len(df)
print(f"Total rows: {total_rows}\n")
print(f"{'Column':<15} {'Type':<10} {'Non-Null':>8} {'Null':>6} {'% Full':>8}  Range / Values")
print("-" * 80)

for col in df.columns:
    dtype = str(df[col].dtype)
    non_null = df[col].notna().sum()
    null = total_rows - non_null
    pct = non_null / total_rows * 100

    if df[col].dtype in ['float64', 'int64']:
        lo, hi = df[col].min(), df[col].max()
        detail = f"{lo:.2f} – {hi:.2f}"
    else:
        top = df[col].value_counts().head(3)
        detail = ", ".join([f"{v} ({c})" for v, c in top.items()])

    print(f"{col:<15} {dtype:<10} {non_null:>8} {null:>6} {pct:>7.1f}%  {detail}")
# Out:
# Run: 2026-02-23 16:24:13
# Total rows: 891
#
# Column          Type       Non-Null   Null   % Full  Range / Values
# --------------------------------------------------------------------------------
# PassengerId     int64           891      0   100.0%  1.00 – 891.00
# Survived        int64           891      0   100.0%  0.00 – 1.00
# Pclass          int64           891      0   100.0%  1.00 – 3.00
# Name            str             891      0   100.0%  Braund, Mr. Owen Harris (1), Cumings, Mrs. John Bradley (Florence Briggs Thayer) (1), Heikkinen, Miss. Laina (1)
# Sex             str             891      0   100.0%  male (577), female (314)
# Age             float64         714    177    80.1%  0.42 – 80.00
# SibSp           int64           891      0   100.0%  0.00 – 8.00
# Parch           int64           891      0   100.0%  0.00 – 6.00
# Ticket          str             891      0   100.0%  347082 (7), 1601 (7), CA. 2343 (7)
# Fare            float64         891      0   100.0%  0.00 – 512.33
# Cabin           str             204    687    22.9%  G6 (4), C23 C25 C27 (4), B96 B98 (4)
# Embarked        str             889      2    99.8%  S (644), C (168), Q (77)

# %%
from datetime import datetime; 
print(f"Run: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# Survival rate by age group
age_bins = [0, 12, 18, 35, 60, 80]
age_labels = ['Child (0-12)', 'Teen (13-18)', 'Young Adult (19-35)', 'Middle Age (36-60)', 'Senior (61+)']

df['AgeGroup'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)

survival_by_age = df.groupby('AgeGroup', observed=True)['Survived'].agg(['count', 'sum', 'mean'])
survival_by_age_by_class = df.groupby(['AgeGroup', 'Pclass'], observed=True)['Survived'].agg(['count', 'sum', 'mean'])
survival_by_age.columns = ['Total', 'Survived', 'SurvivalRate']
survival_by_age['SurvivalRate'] = survival_by_age['SurvivalRate'].map('{:.1%}'.format)

print("Survival Rate by Age Group")
print(f"Note: {df['Age'].isna().sum()} passengers excluded due to missing age\n")
display(survival_by_age)
display(survival_by_age_by_class)
# Out:
# Run: 2026-02-23 16:24:13
# Survival Rate by Age Group
# Note: 177 passengers excluded due to missing age
#                      Total  Survived SurvivalRate
# AgeGroup
# Child (0-12)            69        40        58.0%
# Teen (13-18)            70        30        42.9%
# Young Adult (19-35)    358       137        38.3%
# Middle Age (36-60)     195        78        40.0%
# Senior (61+)            22         5        22.7%
#                             count  sum      mean
# AgeGroup            Pclass
# Child (0-12)        1           4    3  0.750000
#                     2          17   17  1.000000
#                     3          48   20  0.416667
# Teen (13-18)        1          12   11  0.916667
#                     2          12    6  0.500000
#                     3          46   13  0.282609
# Young Adult (19-35) 1          66   50  0.757576
#                     2          94   41  0.436170
#                     3         198   46  0.232323
# Middle Age (36-60)  1          90   55  0.611111
#                     2          47   18  0.382979
#                     3          58    5  0.086207
# Senior (61+)        1          14    3  0.214286
#                     2           3    1  0.333333
#                     3           5    1  0.200000
